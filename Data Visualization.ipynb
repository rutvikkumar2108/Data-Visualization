# %%
import pandas as pd

# %%
df=pd.read_csv("Automobile.csv")

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# %%
sns.relplot(x="symboling", y="normalized_losses", data=df)

# %%
sns.relplot(x="symboling", y="normalized_losses", hue="make", data=df)

# %%
sns.relplot(x="symboling", y="normalized_losses", hue="fuel_type", data=df)

# %%
sns.relplot(x="symboling", y="normalized_losses", size="make", data=df)

# %%
sns.catplot(x="body_style", y="engine_size", data=df)

# %%
sns.catplot(x="body_style", y="engine_size",jitter=False, data=df)

# %%
sns.catplot(x="body_style", y="engine_size", hue="engine_location", data=df)

# %%
sns.catplot(x="body_style", y="engine_size", kind="swarm",aspect=2.0, data=df)

# %%
sns.catplot(x="body_style", y="engine_size", hue="engine_location", kind="swarm",aspect=2.0,data=df)

# %%
sns.catplot(x="body_style", y="engine_size", kind="box", data=df)

# %%
sns.catplot(x="body_style", y="engine_size", hue="fuel_type", kind="box", data=df)

# %%
sns.catplot(x="body_style", y="engine_size", hue="fuel_type", kind="violin" , data=df)

# %%
sns.catplot(x="body_style", y="engine_size", hue="fuel_type", kind="violin" , split= True , data=df)

# %%
sns.catplot(x="body_style", y="engine_size", hue="fuel_type", kind="bar" , data=df)

# %% [markdown]
# # Point plots
# ###### An alternative style for visualizing the same information is offered by the pointplot() function. This function also encodes the value of the estimate with height on the other axis, but rather than show a full bar it just plots the point estimate and confidence interval. Additionally, pointplot connects points from the same hue category. This makes it easy to see how the main relationship is changing as a function of a second variable, because your eyes are quite good at picking up on differences of slopes:

# %%
sns.catplot(x="body_style", y="engine_size", hue="fuel_type", kind="point" , data=df)

# %%
sns.catplot(x="body_style", y="engine_size", hue="fuel_type", col="engine_location", aspect=2.0, kind="swarm" , data=df)

# %%
sns.displot(df.wheel_base, kde=True)

# %%
sns.displot(df.wheel_base,kde=False, rug=True)

# %%
sns.jointplot(x="wheel_base", y="engine_size", data=df)

# %%
sns.jointplot(x=df.engine_size, y=df.wheel_base, kind="hex",data=df)

# %%
sns.jointplot(x="wheel_base", y="engine_size", data=df, kind="kde")

# %%
corrmat=df.corr()
f, ax = plt.subplots(figsize=(9,6))
sns.heatmap(corrmat, vmax=.8 , square=True)
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x="wheel_base", y="engine_size", data=df, kind="box" , height=9, aspect=3.4 ,hue="fuel_type")

# %%
sns.pairplot(df)

# %% [markdown]
# # Drawing multi-panel categorical plots

# %%
sns.catplot(x="fuel_type",
               y = "horsepower",
               hue="number_of_doors", 
               col="drive_wheels", 
               data=df, 
               kind="box");

# %% [markdown]
# # Function to draw linear regression models
# ###### Implot() is one of the most widely used function to quickly plot the Linear Relationship between 2 variables

# %%
sns.lmplot(y="horsepower", x="engine_size", data=df);

# %%
sns.lmplot(y="horsepower", x="engine_size",hue="fuel_type", data=df);
